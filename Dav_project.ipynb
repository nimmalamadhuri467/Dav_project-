# %% [markdown]
# <a href="https://colab.research.google.com/github/nimmalamadhuri467/Dav_project-/blob/main/Dav_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the CSV file
path="/content/data.csv"
df =  pd.read_csv(path)
n=int()
df.head(15)
# Out:
#     Patient ID  Age  Gender Vaccination Date Vaccine Dose  \
# 0            1   55  Female       2021-09-25     2nd Dose
# 1            2   27    Male       2023-07-12     2nd Dose
# 2            3   80    Male       2022-10-01     1st Dose
# 3            4   33    Male       2022-03-17     1st Dose
# 4            5   50  Female       2023-03-26     2nd Dose
# 5            6   74  Female       2022-11-20     2nd Dose
# 6            7   34    Male       2023-01-04      Booster
# 7            8   48  Female       2022-12-25     2nd Dose
# 8            9   73    Male       2022-07-31      Booster
# 9           10   65  Female       2021-06-03     2nd Dose
# 10          11   40  Female       2021-06-29     1st Dose
# 11          12   37  Female       2021-02-07     2nd Dose
# 12          13   66  Female       2023-05-10      Booster
# 13          14   71  Female       2023-11-14     1st Dose
# 14          15   41  Female       2021-06-08     2nd Dose
#
# ...

# %%
df.dtypes
# Out:
# Patient ID                   int64
# Age                          int64
# Gender                      object
# Vaccination Date            object
# Vaccine Dose                object
# Pre-existing Conditions     object
# Heart Attack Date           object
# Severity                    object
# Outcome                     object
# Location                    object
# Blood Pressure              object
# Cholesterol Level            int64
# BMI                        float64
# Smoking History             object
# Diabetes Status             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient ID               550 non-null    int64
#  1   Age                      550 non-null    int64
#  2   Gender                   550 non-null    object
#  3   Vaccination Date         550 non-null    object
#  4   Vaccine Dose             550 non-null    object
#  5   Pre-existing Conditions  479 non-null    object
#  6   Heart Attack Date        153 non-null    object
#  7   Severity                 153 non-null    object
#  8   Outcome                  153 non-null    object
#  9   Location                 550 non-null    object
#  10  Blood Pressure           550 non-null    object
#  11  Cholesterol Level        550 non-null    int64
#  12  BMI                      550 non-null    float64
#  13  Smoking History          550 non-null    object
# ...

# %%
df.describe()
# Out:
#        Patient ID         Age  Cholesterol Level         BMI
# count  550.000000  550.000000         550.000000  550.000000
# mean   275.500000   52.098182         223.143636   26.803273
# std    158.915596   15.843192          43.267955    4.678322
# min      1.000000   25.000000         150.000000   18.500000
# 25%    138.250000   39.000000         187.000000   23.000000
# 50%    275.500000   52.000000         221.000000   26.550000
# 75%    412.750000   66.000000         258.000000   30.700000
# max    550.000000   80.000000         300.000000   35.000000

# %%
df.isnull().sum()
# Out:
# Patient ID                   0
# Age                          0
# Gender                       0
# Vaccination Date             0
# Vaccine Dose                 0
# Pre-existing Conditions     71
# Heart Attack Date          397
# Severity                   397
# Outcome                    397
# Location                     0
# Blood Pressure               0
# Cholesterol Level            0
# BMI                          0
# Smoking History              0
# Diabetes Status              0
# dtype: int64

# %%
df_sorted = df.sort_values(by=['Outcome', 'Age'], ascending=[True, False])
df_sorted.head()
# Out:
#      Patient ID  Age  Gender Vaccination Date Vaccine Dose  \
# 303         304   77    Male       2023-11-07     2nd Dose
# 462         463   75  Female       2023-04-18      Booster
# 410         411   70    Male       2023-01-04     2nd Dose
# 322         323   69  Female       2021-08-12     1st Dose
# 311         312   64  Female       2022-09-25     1st Dose
#
#     Pre-existing Conditions Heart Attack Date Severity       Outcome  \
# 303            Hypertension        2024-02-03    Fatal  Not Survived
# 462           Heart Disease        2024-03-14    Fatal  Not Survived
# 410                     NaN        2023-04-14    Fatal  Not Survived
# 322                 Obesity        2022-02-23    Fatal  Not Survived
# 311                Diabetes        2023-04-11    Fatal  Not Survived
#
#       Location Blood Pressure  Cholesterol Level   BMI Smoking History  \
# 303      Patna      Very High                167  33.9             Yes
# ...

# %%
# Selecting only relevant columns for analysis
selected_columns = ['Patient ID', 'Age', 'Gender', 'Vaccine Dose',
                    'Pre-existing Conditions', 'Outcome', 'Blood Pressure',
                    'Cholesterol Level', 'BMI', 'Smoking History', 'Diabetes Status']

df_selected = df[selected_columns]

# Display the first few rows of the selected columns
df_selected.head()
# Out:
#    Patient ID  Age  Gender  Vaccine Dose Pre-existing Conditions Outcome  \
# 0           1   55  Female           NaN                 Obesity     NaN
# 1           2   27    Male           NaN                     NaN     NaN
# 2           3   80    Male           NaN            Hypertension     NaN
# 3           4   33    Male           NaN                 Smoking     NaN
# 4           5   50  Female           NaN                Diabetes     NaN
#
#    Blood Pressure  Cholesterol Level   BMI Smoking History Diabetes Status
# 0             NaN                189  26.5              No              No
# 1             NaN                150  29.1              No             Yes
# 2             NaN                253  21.8              No              No
# 3             NaN                199  24.6              No              No
# 4             NaN                273  21.0              No              No

# %%
df_subset = df[['Age', 'Gender', 'Vaccine Dose', 'Heart Attack Date', 'Outcome']]
df_subset.head()
# Out:
#    Age  Gender  Vaccine Dose Heart Attack Date Outcome
# 0   55  Female           NaN               NaN     NaN
# 1   27    Male           NaN               NaN     NaN
# 2   80    Male           NaN               NaN     NaN
# 3   33    Male           NaN               NaN     NaN
# 4   50  Female           NaN               NaN     NaN

# %%
df_senior = df[df['Age'] > 60]  # Select individuals above 60
df_senior.head()
# Out:
#     Patient ID  Age  Gender Vaccination Date  Vaccine Dose  \
# 2            3   80    Male       2022-10-01           NaN
# 5            6   74  Female       2022-11-20           NaN
# 8            9   73    Male       2022-07-31           NaN
# 9           10   65  Female       2021-06-03           NaN
# 12          13   66  Female       2023-05-10           NaN
#
#    Pre-existing Conditions Heart Attack Date  Severity   Outcome    Location  \
# 2             Hypertension               NaN       NaN       NaN       Surat
# 5                 Diabetes               NaN       NaN       NaN  Chandigarh
# 8                  Obesity               NaN       NaN       NaN      Nagpur
# 9             Hypertension        2022-01-24  Moderate  Survived      Bhopal
# 12                 Smoking               NaN       NaN       NaN     Lucknow
#
#     Blood Pressure  Cholesterol Level   BMI Smoking History Diabetes Status
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
severity_counts = df['Severity'].value_counts()
severity_counts.plot(kind='bar', colormap='viridis', figsize=(8,5))
plt.xlabel("Severity Level")
plt.ylabel("Count")
plt.title("Distribution of Heart Attack Severity Levels")
plt.show()
print(severity_counts)
# Out:
# Severity
# Mild        45
# Moderate    44
# Severe      36
# Fatal       28
# Name: count, dtype: int64

# %%
# Conversion factor: 1 mmHg = 0.133322 kPa
def convert_bp_to_kpa(mmHg):
    return mmHg * 0.133322

# Applying conversion to Blood Pressure column
df['Blood Pressure (kPa)'] = df['Blood Pressure'] * 0.133322

# Displaying the first few rows
df[['Blood Pressure', 'Blood Pressure (kPa)']].head()
# Out:
#    Blood Pressure  Blood Pressure (kPa)
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Scatter plot of Age vs. Cholesterol Level
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Age'], y=df['Cholesterol Level'], hue=df['Smoking History'], alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Cholesterol Level')
plt.title('Age vs Cholesterol Level')
plt.show()

# %%
df.hist(figsize=(10,8), bins=30)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Create the heatmap
fig, ax = plt.subplots(figsize=(10, 6))
cax = ax.matshow(corr_matrix, cmap="coolwarm")

# Add color bar
plt.colorbar(cax)

# Set axis labels
ax.set_xticks(np.arange(len(corr_matrix.columns)))
ax.set_yticks(np.arange(len(corr_matrix.columns)))
ax.set_xticklabels(corr_matrix.columns, rotation=90)
ax.set_yticklabels(corr_matrix.columns)

plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(data=df)
plt.xticks(rotation=90)  # Rotate labels for better visibility
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Select only numerical columns for correlation analysis
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Smoking History'], y=df['Blood Pressure'], palette='coolwarm')
plt.xlabel('Smoking History')
plt.ylabel('Blood Pressure')
plt.title('Blood Pressure Levels by Smoking History')
plt.show()
# Out:
# <ipython-input-9-bc4331dbd026>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Smoking History'], y=df['Blood Pressure'], palette='coolwarm')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
age_heart_attack = df.groupby('Age')['Heart Attack Date'].count().reset_index()
plt.figure(figsize=(10, 5))
sns.lineplot(x='Age', y='Heart Attack Date', data=age_heart_attack, marker='o', color='crimson')
plt.xlabel("Age")
plt.ylabel("Number of Heart Attack Cases")
plt.title("Trend of Heart Attack Occurrences Across Age Groups")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df.columns = df.columns.str.strip()
sns.relplot(x='Age', y='Cholesterol Level', hue='Outcome', style='Gender', data=df, kind='scatter')
plt.xlabel('Age')
plt.ylabel('Cholesterol Level')
plt.title('Age vs Cholesterol Level by Heart Attack Outcome')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df_sorted = df.sort_values(by='Age')
x = df_sorted['Age']
y = df_sorted['Cholesterol Level']
sns.lineplot(x=x, y=y, color='red', marker='o')
plt.xlabel('Age')
plt.ylabel('Cholesterol Level')
plt.title('Cholesterol Levels Fluctuation Across Age')
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/data.csv")

#prompt: Display the first 10 rows of the dataset to understand its structure
df.head(10)

#prompt: Get dataset info including column names, data types, and missing values
df.info()

#prompt: Get summary statistics for numerical columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient ID               550 non-null    int64
#  1   Age                      550 non-null    int64
#  2   Gender                   550 non-null    object
#  3   Vaccination Date         550 non-null    object
#  4   Vaccine Dose             550 non-null    object
#  5   Pre-existing Conditions  479 non-null    object
#  6   Heart Attack Date        153 non-null    object
#  7   Severity                 153 non-null    object
#  8   Outcome                  153 non-null    object
#  9   Location                 550 non-null    object
#  10  Blood Pressure           550 non-null    object
#  11  Cholesterol Level        550 non-null    int64
#  12  BMI                      550 non-null    float64
#  13  Smoking History          550 non-null    object
# ...

# %%
# Fill numeric columns with mean
df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)

# Fill categorical columns with mode
df.fillna(df.select_dtypes(include=['object']).mode().iloc[0], inplace=True)

# Display updated DataFrame
print(df.head(10))  # Show first 10 rows
# Out:
#    Patient ID  Age  Gender Vaccination Date Vaccine Dose  \
# 0           1   55  Female       2021-09-25     2nd Dose
# 1           2   27    Male       2023-07-12     2nd Dose
# 2           3   80    Male       2022-10-01     1st Dose
# 3           4   33    Male       2022-03-17     1st Dose
# 4           5   50  Female       2023-03-26     2nd Dose
# 5           6   74  Female       2022-11-20     2nd Dose
# 6           7   34    Male       2023-01-04      Booster
# 7           8   48  Female       2022-12-25     2nd Dose
# 8           9   73    Male       2022-07-31      Booster
# 9          10   65  Female       2021-06-03     2nd Dose
#
#   Pre-existing Conditions Heart Attack Date  Severity   Outcome    Location  \
# 0                 Obesity        2022-04-29      Mild  Survived     Chennai
# 1                 Obesity        2022-04-29      Mild  Survived        Agra
# 2            Hypertension        2022-04-29      Mild  Survived       Surat
# ...
